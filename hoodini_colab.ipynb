# %% [markdown]
# # <img src="https://raw.githubusercontent.com/pentamorfico/hoodini-colab/main/assets/images/hoodini_logo.svg" alt="Hoodini Logo" height="28" style="vertical-align: middle;"> hoodini-colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pentamorfico/hoodini-colab/blob/main/hoodini_colab.ipynb)
#
# Interactive parameter configurator for the Hoodini CLI. Configure and run genomic neighborhood analyses with a visual interface - no command-line experience needed!
#
# 📚 **For more information**: Visit the [GitHub repository](https://github.com/pentamorfico/hoodini-colab)
#
# ## ⏱️ Important Note
#
# **Every time you start a new Google Colab session**, you need to install everything and download the databases. This takes approximately **5-15 minutes**.
#
# **After the first analysis completes**, you can run additional analyses without re-downloading everything.
#
# ⚠️ **Remember to change the output folder name** for each new analysis, otherwise your results will be overwritten. Use different names like `results_run1`, `results_run2`, etc.
#
# ## 🚀 Quick Start
#
# Run the cell below **only once**. Running it multiple times may cause errors!

# %%
#@title Run this cell or click in "Run all" or press ctrl+F9 { display-mode: "form" }

# Install and launch hoodini-colab
# !pip install -qq --progress-bar off hoodini-colab==0.1.3

from hoodini_colab import create_launcher

# Create and display the interactive launcher
launcher = create_launcher()
display(launcher)
