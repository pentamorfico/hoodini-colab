# %% [markdown]
# <div align="center">
#   <img src="assets/images/hoodini_logo.svg" alt="Hoodini Logo" width="300">
# </div>
#
# # hoodini-colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hoodini/hoodini-colab/blob/main/hoodini_launcher.ipynb)
#
# Interactive parameter configurator for the Hoodini CLI. Configure your genomic neighborhood analysis with a visual interface.
#
# ## 🚀 Installation
#
# ### Google Colab (Recommended)
# Just run cell 2 below - it will automatically install the package!
#
# ### Local Development
# ```bash
# pip install -e .
# ```
#
# All dependencies (`anywidget`, `traitlets`, `ipython`) will be installed automatically!
#
# ## 📝 Usage
#
# 1. Run cell 2 to install the package
# 2. Run cell 3 to launch the interactive configurator
# 3. Configure your analysis parameters
# 4. Click "Run Hoodini Analysis" button!

# %%
# Install the package (run this cell first!)
# !pip install -q hoodini-colab
# Out:
# Installing anywidget...
# Installing ipython...
# ✅ Using local development version from src/

# %%
from hoodini_launcher import create_launcher

# Create and display the interactive launcher
launcher = create_launcher()
display(launcher)
